# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from src.utils.graphs import saveDatasetBoxplot, saveQQPlot, saveMultiDistributionPDF, savePCACutOffThreshold
from src.utils.functions import mkdir_if_not_exists
from typing import List
from scipy.stats import kstest
from statsmodels.tsa.stattools import adfuller
from scipy import stats

# %%
fistReading =

# %%
pd.DataFrame({'House': range(0, 28), 'FirstReading':['2012-06-01',
'2016-06-09',
'2015-01-27',
'2015-01-30',
'2015-01-30',
'2015-01-30',
'2015-01-30',
'2015-02-21',
'2015-05-01',
'2015-02-21',
'2015-02-21',
'2015-02-21',
'2015-02-21',
'2015-02-21',
'2015-09-29',
'2017-11-01',
'2016-06-01',
'2015-03-16',
'2015-03-26',
'2015-08-21',
'2017-11-01',
'2016-06-29',
'2017-07-27',
'2017-05-13',
'2017-05-15',
'2019-11-29',
'2019-03-06',
'2018-08-01'], "LastReading": ['2015-10-03',
'2019-11-20',
'2018-01-29',
'2018-01-29',
'2018-01-29',
'2018-01-29',
'2018-01-29',
'2018-02-20',
'2018-02-21',
'2018-02-20',
'2018-02-20',
'2018-02-20',
'2018-02-20',
'2018-02-20',
'2018-02-20',
'2019-02-18',
'2017-04-29',
'2018-03-15',
'2018-03-25',
'2018-04-20',
'2018-06-04',
'2018-06-05',
'2020-04-05',
'2020-05-12',
'2020-05-14',
'2020-05-20',
'2020-05-20',
'2020-05-19'], 'Cover':[1.000,
0.994,
0.987,
0.995,
0.995,
0.997,
0.997,
0.987,
0.996,
0.995,
0.990,
0.992,
0.998,
0.995,
0.995,
0.881,
0.996,
0.986,
0.993,
0.998,
0.989,
0.996,
0.985,
0.998,
0.994,
0.997,
0.997,
0.998], 'HouseType':['bungalow',
'duplex',
'modern',
'character',
'modern',
'apartment',
'character',
'special',
'special',
'duplex',
'apartment',
'special',
'modern',
'bungalow',
'apartment',
'apartment',
'bungalow',
'special',
'character',
'laneway',
'apartment',
'apartment',
'modern',
'character',
'apartment',
'apartment',
'special']})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 pd.DataFrame({'House': range(0, 28), 'FirstReading':['2012-06-01',
#       2 '2016-06-09',
#       3 '2015-01-27',
#       4 '2015-01-30',
#       5 '2015-01-30',
#       6 '2015-01-30',
#       7 '2015-01-30',
#       8 '2015-02-21',
#       9 '2015-05-01',
#      10 '2015-02-21',
#      11 '2015-02-21',
#      12 '2015-02-21',
#      13 '2015-02-21',
#      14 '2015-02-21',
#      15 '2015-09-29',
#      16 '2017-11-01',
#      17 '2016-06-01',
#      18 '2015-03-16',
#      19 '2015-03-26',
#      20 '2015-08-21',
#      21 '2017-11-01',
#      22 '2016-06-29',
#      23 '2017-07-27',
#      24 '2017-05-13',
#      25 '2017-05-15',
#      26 '2019-11-29',
#      27 '2019-03-06',
#      28 '2018-08-01'], "LastReading": ['2015-10-03',
#      29 '2019-11-20',
#      30 '2018-01-29',
#      31 '2018-01-29',
#      32 '2018-01-29',
#      33 '2018-01-29',
#      34 '2018-01-29',
#      35 '2018-02-20',
#      36 '2018-02-21',
#      37 '2018-02-20',
#      38 '2018-02-20',
#      39 '2018-02-20',
#      40 '2018-02-20',
#      41 '2018-02-20',
#      42 '2018-02-20',
#      43 '2019-02-18',
#      44 '2017-04-29',
#      45 '2018-03-15',
#      46 '2018-03-25',
#      47 '2018-04-20',
#      48 '2018-06-04',
#      49 '2018-06-05',
#      50 '2020-04-05',
#      51 '2020-05-12',
#      52 '2020-05-14',
#      53 '2020-05-20',
#      54 '2020-05-20',
#      55 '2020-05-19'], 'Cover':[1.000,
#      56 0.994,
#      57 0.987,
#      58 0.995,
#      59 0.995,
#      60 0.997,
#      61 0.997,
#      62 0.987,
#      63 0.996,
#      64 0.995,
#      65 0.990,
#      66 0.992,
#      67 0.998,
#      68 0.995,
#      69 0.995,
#      70 0.881,
#      71 0.996,
#      72 0.986,
#      73 0.993,
#      74 0.998,
#      75 0.989,
#      76 0.996,
#      77 0.985,
#      78 0.998,
#      79 0.994,
#      80 0.997,
#      81 0.997,
#      82 0.998], 'HouseType':['bungalow',
#      83 'duplex',
#      84 'modern',
#      85 'character',
#      86 'modern',
#      87 'apartment',
#      88 'character',
#      89 'special',
#      90 'special',
#      91 'duplex',
#      92 'apartment',
#      93 'special',
#      94 'modern',
#      95 'bungalow',
#      96 'apartment',
#      97 'apartment',
#      98 'bungalow',
#      99 'special',
#     100 'character',
#     101 'laneway',
#     102 'apartment',
#     103 'apartment',
#     104 'modern',
#     105 'character',
#     106 'apartment',
#     107 'apartment',
#     108 'special']})
#
# File ~/opt/anaconda3/envs/consumption-forecasting/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/envs/consumption-forecasting/lib/python3.9/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/consumption-forecasting/lib/python3.9/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/consumption-forecasting/lib/python3.9/site-packages/pandas/core/internals/construction.py:674, in _extract_index(data)
#     672 lengths = list(set(raw_lengths))
#     673 if len(lengths) > 1:
# --> 674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
#     677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#
# ValueError: All arrays must be of the same length

# %%
_id_df = pd.read_csv('data/Pecanstreet/participants_data/15min/15minute_data_austin.csv')
real_participant_ids = list(_id_df['dataid'].unique())
data_columns = _id_df.columns.to_list()

# %%
meta_df = pd.read_csv('data/Pecanstreet/metadata.csv')
meta_df.loc[meta_df['building_type']=='Single-Family Home 001 (Master)','building_type']='Single-Family Home'
meta_data_df = meta_df.copy()
house_types = meta_data_df[meta_data_df['active_record'] == 'yes']['building_type'].value_counts()

# %%
house_types
# Out:
# Single-Family Home    1136
# Town Home               24
# Apartment                9
# Sales                    2
# Mobile Home              1
# Name: building_type, dtype: int64

# %%
plt.bar(house_types.index, (house_types.values/house_types.values.sum() * 100))
plt.xticks(rotation=90)
plt.show()

# %%
meta_df.drop(axis=0, index=0, inplace=True)

# %%
meta_df['dataid'] = meta_df['dataid'].astype(int)

# %%
meta_df = meta_df[(meta_df['active_record'] == 'yes') & (meta_df['dataid'].isin(real_participant_ids))]

# %%
default_columns = [item for item in data_columns if item in meta_df.columns.to_list()]

# %%
present_values = meta_df[default_columns]
_id_values = present_values[present_values['dataid'] == 661].count()

# %%
present_values
# Out:
#       dataid air1 air2 air3 airwindowunit1 aquarium1 bathroom1 bathroom2  \
# 47       661  yes  NaN  NaN            NaN       NaN       yes       NaN
# 52      1642  yes  NaN  NaN            NaN       NaN       yes       NaN
# 58      2335  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 64      2818  yes  NaN  NaN            NaN       NaN       yes       NaN
# 68      3039  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 69      3456  yes  NaN  NaN            NaN       NaN       yes       NaN
# 74      4031  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 80      4767  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 91      7536  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 137     7951  yes  yes  NaN            NaN       NaN       yes       yes
# 220     5746  yes  NaN  NaN            yes       NaN       NaN       NaN
# 223     6139  yes  NaN  NaN            NaN       NaN       NaN       yes
# 249     9922  yes  yes  NaN            NaN       NaN       NaN       NaN
# 318     3538  yes  NaN  NaN            NaN       NaN       yes       NaN
# 324     4373  yes  NaN  NaN            NaN       NaN       yes       NaN
# 342     7800  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 348     8156  yes  NaN  NaN            NaN       NaN       yes       NaN
# 349     8386  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 386     9278  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 1237    7719  yes  NaN  NaN            NaN       NaN       NaN       NaN
# 1244    2361  yes  NaN  NaN            NaN       NaN       yes       NaN
#
#      bedroom1 bedroom2  ... solar solar2 sprinkler1 sumppump1 utilityroom1  \
# 47        NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 52        NaN      NaN  ...   yes    NaN        NaN       NaN          yes
# 58        NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 64        yes      NaN  ...   yes    NaN        yes       NaN          NaN
# 68        NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 69        yes      NaN  ...   yes    NaN        NaN       NaN          NaN
# 74        yes      NaN  ...   yes    NaN        NaN       NaN          NaN
# 80        NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 91        yes      yes  ...   yes    NaN        NaN       NaN          NaN
# 137       NaN      NaN  ...   NaN    NaN        NaN       NaN          NaN
# 220       NaN      yes  ...   NaN    NaN        NaN       NaN          NaN
# 223       NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 249       yes      yes  ...   NaN    NaN        NaN       NaN          yes
# 318       yes      NaN  ...   yes    NaN        yes       NaN          NaN
# 324       yes      NaN  ...   yes    NaN        NaN       NaN          NaN
# 342       yes      NaN  ...   yes    NaN        NaN       NaN          NaN
# 348       NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 349       yes      NaN  ...   NaN    NaN        NaN       NaN          NaN
# 386       NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
# 1237      yes      NaN  ...   yes    NaN        NaN       NaN          NaN
# 1244      NaN      NaN  ...   yes    NaN        NaN       NaN          NaN
#
#      venthood1 waterheater1 waterheater2 wellpump1 winecooler1
# 47         NaN          NaN          NaN       NaN         NaN
# 52         yes          NaN          NaN       NaN         NaN
# 58         yes          NaN          NaN       NaN         NaN
# 64         yes          NaN          NaN       NaN         NaN
# 68         NaN          yes          yes       yes         NaN
# 69         NaN          NaN          NaN       NaN         NaN
# 74         NaN          NaN          NaN       NaN         NaN
# 80         NaN          NaN          NaN       NaN         NaN
# 91         NaN          yes          NaN       NaN         NaN
# 137        NaN          yes          NaN       NaN         NaN
# 220        NaN          NaN          NaN       NaN         NaN
# 223        NaN          NaN          NaN       NaN         NaN
# 249        NaN          NaN          NaN       NaN         NaN
# 318        NaN          NaN          NaN       NaN         NaN
# 324        yes          NaN          NaN       NaN         NaN
# 342        yes          NaN          NaN       NaN         NaN
# 348        NaN          NaN          NaN       NaN         NaN
# 349        NaN          NaN          NaN       NaN         NaN
# 386        NaN          NaN          NaN       NaN         NaN
# 1237       yes          NaN          NaN       NaN         NaN
# 1244       yes          NaN          NaN       NaN         NaN
#
# [21 rows x 76 columns]

# %%
filled = np.count_nonzero(_id_values.values) - 1
nonfilled = len(_id_values.values) - filled - 1
print('filled:', filled)
print('non-filled:', nonfilled)
print(len(_id_values.values))
# Out:
# filled: 14
# non-filled: 61
# 76

# %%
df = pd.read_csv('data/Pecanstreet/participants_data/1min/661.csv')

# %%
df

# %%
df.isna().sum().sum()

# %%
df.isna().sum()

# %%
def createDataDict(dataset: str, _id: str, data_type: str, resolutions: List[str]):
    return {
            resolution: 
                        {'scaler': MinMaxScaler(feature_range=(-1,1)), 
                         'df': pd.read_csv(f'data/{dataset}/participants_data/{resolution}/features/{data_type}/{_id}.csv')} for resolution in resolutions}

# %%
pecan_dict = createDataDict(dataset='Pecanstreet', 
                            _id='661_features', 
                            data_type='all', 
                            resolutions=['1min', '15min', '1hour'])

# %%
hue_dict = createDataDict(dataset='HUE',
                         _id='residential_1',
                         data_type='all',
                         resolutions=['1hour'])

# %%
mkdir_if_not_exists('etc/imgs/Pecanstreet/statistical-study')
mkdir_if_not_exists('etc/imgs/HUE/statistical-study')
PCA_data = []

# %%
pca_style = {
    'Pecanstreet': {
        '1min':{
            'line-style': '-',
            'marker': 'o',
            'color': 'b',
        },
        '15min':{
            'line-style': '-',
            'marker': 'o',
            'color': 'g',
        },
        '1hour':{
            'line-style': '-',
            'marker': 'o',
            'color': 'c',
        }
    },
    'HUE': {
        '1hour': {
            'line-style': '--',
            'marker': 's',
            'color': 'k'
        }
        
    }

}

# %%
def makePCACumSum(data):
    data.dropna(inplace=True)
    pca = PCA(n_components = 0.99)
    features_pca = pca.fit(data)
    return np.cumsum(pca.explained_variance_ratio_), pca.transform(data)

# %%
for resolution in pecan_dict.keys():
    scaler = pecan_dict[resolution]['scaler']
    df = pecan_dict[resolution]['df']
    pecan_dict[resolution]['scaler'] = scaler.fit(df)
    pecan_dict[resolution]['df'] = pd.DataFrame(data=scaler.transform(df),
                                       index=df.index, columns=df.columns)
    
    pca_cumulative, transform_data = makePCACumSum(pecan_dict[resolution]['df'])

    
    PCA_data.append((pca_cumulative, 
                     pca_style['Pecanstreet'][resolution]['marker'],
                     pca_style['Pecanstreet'][resolution]['line-style'],
                     pca_style['Pecanstreet'][resolution]['color'],
                     f'Pecanstreet - {resolution}'
                    ))
    saveDatasetBoxplot(df=pecan_dict[resolution]['df'], 
                       path='etc/imgs/Pecanstreet/statistical-study/', 
                       filename=f"Pecanstreet-{resolution}_all_boxplot_df")
    plt.show()

# %%
for resolution in hue_dict.keys():
    scaler = hue_dict[resolution]['scaler']
    df = hue_dict[resolution]['df']
    hue_dict[resolution]['scaler'] = scaler.fit(df)
    hue_dict[resolution]['df'] = pd.DataFrame(data=scaler.transform(df),
                                       index=df.index, columns=df.columns)
    
    pca_cumulative, transform_data = makePCACumSum(hue_dict[resolution]['df'])


    PCA_data.append((pca_cumulative, 
                     pca_style['HUE'][resolution]['marker'],
                     pca_style['HUE'][resolution]['line-style'],
                     pca_style['HUE'][resolution]['color'],
                     f'HUE - {resolution}'
                    ))

    saveDatasetBoxplot(df=hue_dict[resolution]['df'], 
                       path='etc/imgs/HUE/statistical-study/', 
                       filename=f"HUE-{resolution}_all_boxplot_df")
    plt.show()

# %%
savePCACutOffThreshold(PCA_data, 'etc/imgs/dataset_comparison', 'limite_confianca_comparacao', None)

# %%
df = pd.DataFrame({
                'Pecanstreet - 1min': pecan_dict['1min']['df']['consumption'],
                'Pecanstreet - 15min': pecan_dict['15min']['df']['consumption'],
                'Pecanstreet - 1hour': pecan_dict['1hour']['df']['consumption'],
                'HUE - 1hour': hue_dict['1hour']['df']['consumption'],
})

# %%
df_data = [(df[column].dropna(), column) for column in df.columns]
saveMultiDistributionPDF(data = df_data, path='etc/imgs/dataset_comparison/', filename='pdf_study')
plt.show()

# %%
for column in df.columns:
    data = df[column].dropna()
    ks_statistic, p_value = kstest(data, 'norm')

    print("********* Valor estatístico de Kolmogorov-Smirnov ************", ks_statistic)
    print("********* p-value *************", p_value, "H_o rejeitada: estacionária" if p_value < 0.05 else "não estacionária")
    
    saveQQPlot(data=data, path='etc/imgs/dataset_comparison/', filename=f"qq_plot_{column}")
    plt.show()

# %%
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')
fig, axs = plt.subplots(1, len(df.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    data = df.iloc[:,i]
    data.dropna(inplace=True)
    ax.boxplot(data, flierprops=red_circle)
    df.iloc[:,i]
    ax.set_title(df.columns[i], fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    ax.set_xlabel('Consumo')

axs[0].set_ylabel('Valores normalizados')
plt.savefig(f'etc/imgs/dataset_comparison/boxplot_dataset_consumption_comparison.eps', dpi=200, bbox_inches='tight')
plt.savefig(f'etc/imgs/dataset_comparison/boxplot_dataset_consumption_comparison.svg', dpi=200, bbox_inches='tight')
plt.savefig(f'etc/imgs/dataset_comparison/boxplot_dataset_consumption_comparison.png', dpi=200, bbox_inches='tight')
plt.tight_layout()
