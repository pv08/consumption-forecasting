# %%
import matplotlib.pyplot as plt
from src.pecan_dataport.participant_preprocessing import PecanParticipantPreProcessing

# %%
pecan_dataset = PecanParticipantPreProcessing('661_test_30_all', 'data/participants_data/1min/', 60, task='test')
# Out:
# [!] - Trainable dataframe shape - (129086, 28)
# [*] Train dataframe shape: (90360, 28)
# [*] Validation dataframe shape: (25817, 28)
# [*] Test dataframe shape: (12909, 28)
# ...
# 100%|█████████████████████████████████████████████████████████████████████████| 12849/12849 [00:01<00:00, 12749.90it/s]
# [!] Val sequence shape: (60, 28)
# [!] Test sequence shape: (60, 28)

# %%
pecan_std_df = pecan_dataset.total_df #Dataframe com dados pre-processados normalizados
pecan_std_df
# Out:
#         generation  time_hour  time_minute  month  day_of_week  day  \
# 0        -1.000000  -1.000000    -1.000000   -1.0    -1.000000 -1.0
# 1        -1.000000  -1.000000    -0.966102   -1.0    -1.000000 -1.0
# 2        -1.000000  -1.000000    -0.932203   -1.0    -1.000000 -1.0
# 3        -1.000000  -1.000000    -0.898305   -1.0    -1.000000 -1.0
# 4        -1.000000  -1.000000    -0.864407   -1.0    -1.000000 -1.0
# ...            ...        ...          ...    ...          ...  ...
# 129081    0.200740   0.391304    -0.288136    1.0     0.666667  1.0
# 129082    0.183577   0.391304    -0.254237    1.0     0.666667  1.0
# 129083    0.181558   0.391304    -0.220339    1.0     0.666667  1.0
# 129084    0.201077   0.391304    -0.186441    1.0     0.666667  1.0
# 129085    0.269056   0.391304    -0.152542    1.0     0.666667  1.0
#
#         week_of_year  consumption_change  consumption  maxtempC  ...  \
# 0               -1.0            0.056711    -0.491266   -0.8125  ...
# ...

# %%
lstm_shap_columns = [
            "day",
            "consumption",
            "cosumption_change",
            "moon_illumination",
            "mintempC",
            "day_of_week",
            "generation",
            "humidity",
            "week_of_year",
            "sonHour",
            "pressure",
            "DewPointC",
            "WindChillC",
            "visibility",
            "maxtempC",
            "tempC",
            "windspeedKmph",
            "FeelsLikeC",
            "time_minute",
            "precipMM"
]

# %%
shap_values_lstm = pecan_std_df[pecan_std_df.columns & lstm_shap_columns]
# Out:
# Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.

# %%
shap_values_lstm.to_csv("data/participants_data/1min//features/661_test_30_LSTM_shap_features.csv", index=False)
