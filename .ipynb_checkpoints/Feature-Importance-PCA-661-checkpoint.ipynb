# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from src.pecan_dataport.participant_preprocessing import PecanParticipantPreProcessing
from sklearn.decomposition import PCA
from scipy import stats

# %%
pecan_dataset = PecanParticipantPreProcessing('661_test_30_pca', 'data/participants_data/1min/',60)
# Out:
# [!] - Trainable dataframe shape - (129086, 18)
# [*] Train dataframe shape: (90360, 18)
# [*] Validation dataframe shape: (25817, 18)
# [*] Test dataframe shape: (12909, 18)
# 100%|█████████████████████████████████████████████████████████████████████████| 90300/90300 [00:07<00:00, 12704.16it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 12849/12849 [00:00<00:00, 14217.89it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 25757/25757 [00:01<00:00, 14195.56it/s]
# [!] Train sequence shape: (60, 18)
# [!] Test sequence shape: (60, 18)
# [!] Val sequence shape: (60, 18)
# [!] Len of train, val and test sequence: 90300 25757 12849

# %%
pecan_std_df = pecan_dataset.total_df #Dataframe com dados pre-processados normalizados

# %%
features_names = [x for x in pecan_std_df.columns if x != "consumption"]
features_values = pecan_std_df[features_names].values
target_values = np.array(pecan_std_df['consumption'])
# Out:
# array([-0.49126583, -0.49143141, -0.4915142 , ..., -0.73524298,
#        -0.74120374, -0.77796175])

# %%
pca = PCA(n_components = 0.99)
features_pca = pca.fit(pecan_std_df)
loadings = features_pca.components_

# %%
plt.figure(figsize=(15, 5))
plt.ylim(0.0,1.1)
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--', color='b')
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');
plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red')
plt.grid(axis='x')

# %%
print(pca.n_components_)
# Out:
# 15

# %%
pca_result_df = pd.DataFrame(pca.components_, columns = pecan_std_df.columns)
pca_result_df
# Out:
#     generation  time_hour  time_minute     month  day_of_week       day  \
# 0     0.002698   0.011434     0.000166 -0.569467    -0.037256 -0.124183
# 1    -0.196877  -0.071049     0.000213 -0.083392     0.204725  0.005693
# 2    -0.035975  -0.006817     0.001203  0.271364    -0.489787 -0.322699
# 3    -0.030971  -0.194268    -0.000359 -0.259969    -0.748439  0.484393
# 4    -0.064443  -0.232963     0.000086  0.184850    -0.100035 -0.481633
# 5    -0.078532  -0.909674     0.002589  0.004494     0.151361  0.001148
# 6     0.000681   0.002493     0.999980 -0.000358    -0.000409  0.000454
# 7     0.333775  -0.001602     0.000391  0.081086    -0.203151 -0.404552
# 8     0.771918  -0.161009     0.001298 -0.028786     0.164755  0.200900
# 9    -0.077033   0.146042     0.000264  0.078046     0.168189  0.257520
# 10    0.117799   0.131297    -0.000027 -0.063059    -0.127890 -0.112511
# 11    0.065488  -0.086531    -0.000111  0.110774    -0.007368  0.076394
# 12   -0.356673  -0.051430    -0.000382  0.000534     0.049119  0.052241
# 13   -0.002328  -0.022366    -0.000084 -0.033770    -0.040918 -0.027658
# 14   -0.000142  -0.005007    -0.000119 -0.004853     0.011059 -0.046367
#
#     week_of_year  consumption  mintempC  totalSnow_cm   sunHour   uvIndex  \
# 0      -0.662560     0.001047 -0.266773      0.024818 -0.047179 -0.341813
# 1      -0.098903     0.052624  0.104503      0.014667 -0.537230 -0.030402
# 2       0.172696    -0.003424 -0.250977      0.073995 -0.035225 -0.390260
# 3       0.065588    -0.012764  0.052453      0.020667 -0.041299  0.099423
# 4      -0.051535     0.014730 -0.042308     -0.034062  0.025899 -0.049567
# 5      -0.013754     0.030562 -0.051518     -0.002630  0.208678 -0.025276
# 6      -0.000094     0.005507  0.000659     -0.000129 -0.000335  0.000790
# 7      -0.112178    -0.110250  0.121227     -0.043126 -0.121893  0.154749
# 8       0.059083    -0.233152 -0.013310      0.016750 -0.088109 -0.074212
# 9       0.199372     0.021881 -0.261334      0.023312  0.296861 -0.533547
# 10     -0.119170    -0.034846  0.127256     -0.054981  0.193092  0.203140
# 11      0.163214     0.010507 -0.112022      0.051294 -0.691365 -0.223471
# 12      0.006471     0.140791  0.149518     -0.039894 -0.165418  0.172531
# 13     -0.027015    -0.007685  0.715393     -0.393922  0.055364 -0.457459
# 14     -0.048125     0.019120  0.353301      0.908023  0.071761 -0.094038
#
#     moon_illumination  cloudcover  humidity  precipMM  visibility  \
# 0           -0.012854   -0.085772 -0.142473 -0.016467    0.024896
# 1           -0.067459    0.639709  0.359097  0.032759   -0.222777
# 2           -0.462382    0.231517 -0.125439  0.011484    0.002030
# 3            0.232174    0.116893  0.063649  0.036284   -0.026857
# 4            0.762077    0.099348 -0.008140  0.015255   -0.077525
# 5           -0.236408   -0.099250  0.070068 -0.003300   -0.101177
# 6            0.001086   -0.000432  0.000202 -0.000010    0.000416
# 7           -0.026763    0.052180 -0.068691 -0.027504   -0.041572
# 8            0.052884    0.281299 -0.301341  0.017335   -0.047156
# 9            0.233056    0.144210 -0.046579  0.087832   -0.365938
# 10          -0.154493   -0.153687  0.128962  0.037932   -0.841486
# 11           0.078201   -0.593565  0.018043  0.089916   -0.181837
# 12          -0.016981    0.103255 -0.840738 -0.051258   -0.206118
# 13          -0.035705   -0.061066 -0.012067  0.317453    0.090205
# 14           0.021905   -0.027473 -0.026956  0.172250    0.000813
#
#     winddirDegree
# 0       -0.014681
# 1        0.025161
# 2       -0.214199
# 3        0.077643
# 4       -0.244004
# 5        0.120509
# 6       -0.000071
# 7        0.765729
# 8       -0.251093
# 9        0.413848
# 10      -0.221482
# 11       0.017260
# 12       0.033959
# 13      -0.042039
# 14       0.006791

# %%
import seaborn as sns
plt.figure(figsize=(20, 20))
plt.title(f'[`PCA`] - Features components', fontsize=15)

ax = sns.heatmap(pca_result_df,  cmap="YlGnBu")
plt.xlabel('Features', fontsize=15)
plt.ylabel('[PC] - Components', fontsize=15)
# plt.savefig(f'etc/imgs/features/feature_importance_PCA_661_test_13.svg', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 import seaborn as sns
#       2 plt.figure(figsize=(20, 20))
#       3 plt.title(f'[`PCA`] - Features components', fontsize=15)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
n_pcs= pca.n_components_ 
# get the index of the most important feature on EACH component
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]
initial_feature_names = pecan_dataset.get_test_data().columns
# get the most important feature names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

np.abs(pca.components_[1])
most_important_names
# Out:
# ['year_cos',
#  'day_cos',
#  'day_sin',
#  'day_of_week',
#  'day',
#  'time_minute',
#  'generation',
#  'time_hour',
#  'year_cos']
