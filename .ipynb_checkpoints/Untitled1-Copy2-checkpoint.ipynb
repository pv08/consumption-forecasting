# %%
import pandas as pd
import wwo_hist
import os
from src.utils.functions import mkdir_if_not_exists
import os
import datetime
import numpy as np
from tqdm import tqdm

# %%
def mk_weather_data(api, location, start, end, freq):
    mkdir_if_not_exists("data/weather_data/")
    os.chdir("data/weather_data/")
    
    hist_weather_data = wwo_hist.retrieve_hist_data(
        api_key=key, 
        location_list=locations, 
        start_date=start, 
        end_date=end, 
        frequency=freq, 
        location_label=False, 
        export_csv=True, 
        store_df=False
    )
    os.chdir("../../")
    return pd.read_csv(f'data/weather_data/{location[0]}.csv')

# %%
par_data = pd.read_csv('data/participants_data/1min/661.csv')
par_data.sort_values(by=['localminute'])
par_data['date'] = pd.to_datetime(par_data['localminute'])

# %%
par_data
# Out:
#         dataid             localminute  air1  air2  air3  airwindowunit1  \
# 0          661  2018-01-01 01:21:00-06   0.0   NaN   NaN             NaN
# 1          661  2018-01-01 01:00:00-06   0.0   NaN   NaN             NaN
# 2          661  2018-01-01 01:01:00-06   0.0   NaN   NaN             NaN
# 3          661  2018-01-01 01:02:00-06   0.0   NaN   NaN             NaN
# 4          661  2018-01-01 01:03:00-06   0.0   NaN   NaN             NaN
# ...        ...                     ...   ...   ...   ...             ...
# 525525     661  2018-02-01 10:52:00-06   0.0   NaN   NaN             NaN
# 525526     661  2018-02-01 10:53:00-06   0.0   NaN   NaN             NaN
# 525527     661  2018-02-01 10:54:00-06   0.0   NaN   NaN             NaN
# 525528     661  2018-02-01 10:55:00-06   0.0   NaN   NaN             NaN
# 525529     661  2018-02-01 10:56:00-06   0.0   NaN   NaN             NaN
#
#         aquarium1  bathroom1  bathroom2  bedroom1  ...  sumppump1  \
# 0             NaN        NaN        NaN       NaN  ...        NaN
# 1             NaN        NaN        NaN       NaN  ...        NaN
# 2             NaN        NaN        NaN       NaN  ...        NaN
# 3             NaN        NaN        NaN       NaN  ...        NaN
# 4             NaN        NaN        NaN       NaN  ...        NaN
# ...           ...        ...        ...       ...  ...        ...
# 525525        NaN      0.004        NaN       NaN  ...        NaN
# 525526        NaN      0.004        NaN       NaN  ...        NaN
# 525527        NaN      0.004        NaN       NaN  ...        NaN
# 525528        NaN      0.004        NaN       NaN  ...        NaN
# 525529        NaN      0.004        NaN       NaN  ...        NaN
#
#         utilityroom1  venthood1  waterheater1  waterheater2  wellpump1  \
# 0                NaN        NaN           NaN           NaN        NaN
# 1                NaN        NaN           NaN           NaN        NaN
# 2                NaN        NaN           NaN           NaN        NaN
# 3                NaN        NaN           NaN           NaN        NaN
# 4                NaN        NaN           NaN           NaN        NaN
# ...              ...        ...           ...           ...        ...
# 525525           NaN        NaN           NaN           NaN        NaN
# 525526           NaN        NaN           NaN           NaN        NaN
# 525527           NaN        NaN           NaN           NaN        NaN
# 525528           NaN        NaN           NaN           NaN        NaN
# 525529           NaN        NaN           NaN           NaN        NaN
#
#         winecooler1    leg1v    leg2v                       date
# 0               NaN      NaN      NaN  2018-01-01 01:21:00-06:00
# 1               NaN      NaN      NaN  2018-01-01 01:00:00-06:00
# 2               NaN      NaN      NaN  2018-01-01 01:01:00-06:00
# 3               NaN      NaN      NaN  2018-01-01 01:02:00-06:00
# 4               NaN      NaN      NaN  2018-01-01 01:03:00-06:00
# ...             ...      ...      ...                        ...
# 525525          NaN  122.775  123.431  2018-02-01 10:52:00-06:00
# 525526          NaN  122.776  123.432  2018-02-01 10:53:00-06:00
# 525527          NaN  122.798  123.439  2018-02-01 10:54:00-06:00
# 525528          NaN  122.945  123.319  2018-02-01 10:55:00-06:00
# 525529          NaN  122.880  123.248  2018-02-01 10:56:00-06:00
#
# [525530 rows x 80 columns]

# %%
key='53a4996903bc42d9a47162143210210' # API key obtained from https://www.worldweatheronline.com/
locations=['162.89.0.47'] # list of strings containg US Zipcode, UK Postcode, Canada Postalcode, IP address, Latitude/Longitude (decimal degree) or city name  
start='01-01-2018' # date when desired scraping period starts; preferred date format: 'dd-mmm-yyyy'
end='31-12-2018' # date when desired scraping period ends; preferred date format: 'dd-mmm-yyyy
freq=1 # frequency between observations; possible values 1 (1 hour), 3 (3 hours), 6 (6 hours), 12 (12 hours (day/night)) or 24 (daily averages)weather_df = mk_weather_data()

# weather_df = mk_weather_data(key, locations, start, end, freq)
weather_df = pd.read_csv(f'data/weather_data/162.89.0.47.csv')

# %%
weather_df['date'] = pd.to_datetime(weather_df['date_time'])
del weather_df['moonrise'], weather_df['moonset'], weather_df['sunrise'], weather_df['sunset']
weather_df
# Out:
#                 date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     2018-01-01 00:00:00         1        -4           0.0     10.0        1
# 1     2018-01-01 01:00:00         1        -4           0.0     10.0        1
# 2     2018-01-01 02:00:00         1        -4           0.0     10.0        1
# 3     2018-01-01 03:00:00         1        -4           0.0     10.0        1
# 4     2018-01-01 04:00:00         1        -4           0.0     10.0        1
# ...                   ...       ...       ...           ...      ...      ...
# 8755  2018-12-31 19:00:00        17         5           0.0     10.1        3
# 8756  2018-12-31 20:00:00        17         5           0.0     10.1        3
# 8757  2018-12-31 21:00:00        17         5           0.0     10.1        3
# 8758  2018-12-31 22:00:00        17         5           0.0     10.1        3
# 8759  2018-12-31 23:00:00        17         5           0.0     10.1        3
#
#       moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  ...  cloudcover  \
# 0                    97         -9          -9          -2  ...          93
# 1                    97        -10          -9          -2  ...          74
# 2                    97        -11          -9          -3  ...          55
# 3                    97        -13         -10          -3  ...          37
# 4                    97        -13         -10          -3  ...          35
# ...                 ...        ...         ...         ...  ...         ...
# 8755                 36          4          10          11  ...           5
# 8756                 36          4          10          10  ...           9
# 8757                 36          4          10          10  ...          14
# 8758                 36          5          10          10  ...           9
# 8759                 36          6          11          10  ...           5
#
#       humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# 0           57       0.0      1037     -2          10              9
# 1           54       0.0      1037     -2          10             12
# 2           51       0.0      1038     -3          10             14
# 3           48       0.0      1038     -3          10             17
# 4           45       0.0      1039     -3          10             15
# ...        ...       ...       ...    ...         ...            ...
# 8755        64       0.0      1015     11          10            220
# 8756        68       0.0      1016     10          10            218
# 8757        72       0.0      1016      9          10            216
# 8758        73       0.0      1017     10          10            217
# 8759        74       0.0      1017     10          10            218
#
#       windspeedKmph     location                date
# 0                25  162.89.0.47 2018-01-01 00:00:00
# 1                25  162.89.0.47 2018-01-01 01:00:00
# 2                26  162.89.0.47 2018-01-01 02:00:00
# 3                26  162.89.0.47 2018-01-01 03:00:00
# 4                25  162.89.0.47 2018-01-01 04:00:00
# ...             ...          ...                 ...
# 8755              6  162.89.0.47 2018-12-31 19:00:00
# 8756              3  162.89.0.47 2018-12-31 20:00:00
# 8757              1  162.89.0.47 2018-12-31 21:00:00
# 8758              1  162.89.0.47 2018-12-31 22:00:00
# 8759              1  162.89.0.47 2018-12-31 23:00:00
#
# [8760 rows x 22 columns]

# %%
print(weather_df.columns[1:-1])
# Out:
# Index(['maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'moon_illumination', 'DewPointC', 'FeelsLikeC', 'HeatIndexC',
#        'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity', 'precipMM',
#        'pressure', 'tempC', 'visibility', 'winddirDegree', 'windspeedKmph',
#        'location'],
#       dtype='object')

# %%
weather = []
for _, row in tqdm(weather_df.iterrows(), total=weather_df.shape[0]):
    values = {
        'date':datetime.datetime.strftime(row.date, '%Y-%m-%d'),
        'hour':datetime.datetime.strftime(row.date, '%H:%M')
    }
    for columns in weather_df.columns[1:-1]:
        values[columns] = row[columns]
    weather.append(values)
weather_df = pd.DataFrame(weather)
weather_df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 8760/8760 [00:01<00:00, 7844.12it/s]
#             date   hour  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     2018-01-01  00:00         1        -4           0.0     10.0        1
# 1     2018-01-01  01:00         1        -4           0.0     10.0        1
# 2     2018-01-01  02:00         1        -4           0.0     10.0        1
# 3     2018-01-01  03:00         1        -4           0.0     10.0        1
# 4     2018-01-01  04:00         1        -4           0.0     10.0        1
# ...          ...    ...       ...       ...           ...      ...      ...
# 8755  2018-12-31  19:00        17         5           0.0     10.1        3
# 8756  2018-12-31  20:00        17         5           0.0     10.1        3
# 8757  2018-12-31  21:00        17         5           0.0     10.1        3
# 8758  2018-12-31  22:00        17         5           0.0     10.1        3
# 8759  2018-12-31  23:00        17         5           0.0     10.1        3
#
#       moon_illumination  DewPointC  FeelsLikeC  ...  WindGustKmph  cloudcover  \
# 0                    97         -9          -9  ...            34          93
# 1                    97        -10          -9  ...            35          74
# 2                    97        -11          -9  ...            35          55
# 3                    97        -13         -10  ...            36          37
# 4                    97        -13         -10  ...            34          35
# ...                 ...        ...         ...  ...           ...         ...
# 8755                 36          4          10  ...            17           5
# 8756                 36          4          10  ...            17           9
# 8757                 36          4          10  ...            16          14
# 8758                 36          5          10  ...            14           9
# 8759                 36          6          11  ...            12           5
#
#       humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# 0           57       0.0      1037     -2          10              9
# 1           54       0.0      1037     -2          10             12
# 2           51       0.0      1038     -3          10             14
# 3           48       0.0      1038     -3          10             17
# 4           45       0.0      1039     -3          10             15
# ...        ...       ...       ...    ...         ...            ...
# 8755        64       0.0      1015     11          10            220
# 8756        68       0.0      1016     10          10            218
# 8757        72       0.0      1016      9          10            216
# 8758        73       0.0      1017     10          10            217
# 8759        74       0.0      1017     10          10            218
#
#       windspeedKmph     location
# 0                25  162.89.0.47
# 1                25  162.89.0.47
# 2                26  162.89.0.47
# 3                26  162.89.0.47
# 4                25  162.89.0.47
# ...             ...          ...
# 8755              6  162.89.0.47
# 8756              3  162.89.0.47
# 8757              1  162.89.0.47
# 8758              1  162.89.0.47
# 8759              1  162.89.0.47
#
# [8760 rows x 22 columns]

# %%
def insert_weather_data(date, hour):
    values = {}
    loc = weather_df.loc[(weather_df['date'] == str(date)) & (weather_df['hour'] == f'{str(hour)}:00')]
    for _, row in loc.iterrows():
        for columns in loc.columns[2:-1]:
            values[columns] = row[columns]
    return values

# %%
new_data = par_data.copy()

new_data['generation_solar1'] = np.where(new_data['solar'] < 0, 0, new_data['solar'])
new_data['generation_solar2'] = np.where(new_data['solar2'] < 0, 0, new_data['solar2'])

del new_data['dataid'], new_data['solar'], new_data['solar2'], new_data['leg1v'], new_data['leg2v']
data_columns = list(new_data.columns)

consumption = data_columns[1:len(data_columns) - 3]
new_data["sum_consumption"] = new_data[consumption].sum(axis=1)

generation = data_columns[len(data_columns) - 2:]
new_data["sum_generation"] = new_data[generation].sum(axis=1)

compiled = pd.DataFrame({'date': new_data['localminute'], 'consumption': new_data['sum_consumption'],
                         'generation': new_data['sum_generation'], 'copy_date': new_data['date']})
df = compiled.copy()

rows = []

for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    date_format = pd.Timestamp(row.date)
    row_data = dict(
        date=datetime.datetime.strftime(row.copy_date, '%Y-%m-%d'),
        hour=datetime.datetime.strftime(row.copy_date, '%H:%M'),
        consumption=row.consumption,
        generation=row.generation,
        time_hour=date_format.hour,
        time_minute=date_format.minute,
        month=date_format.month,
        day_of_week=date_format.dayofweek,
        day=date_format.day,
        week_of_year=date_format.week
    )
    weather_data = insert_weather_data(datetime.datetime.strftime(row.copy_date, '%Y-%m-%d'), datetime.datetime.strftime(row.copy_date, '%H'))
    row_data.update(weather_data)
    rows.append(row_data)
features_df = pd.DataFrame(rows)
features_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 525530/525530 [15:47<00:00, 554.40it/s]
#               date   hour  consumption  generation  time_hour  time_minute  \
# 0       2018-01-01  01:21        2.415       0.000          1           21
# 1       2018-01-01  01:00        2.431       0.000          1            0
# 2       2018-01-01  01:01        2.410       0.000          1            1
# 3       2018-01-01  01:02        2.326       0.000          1            2
# 4       2018-01-01  01:03        2.150       0.000          1            3
# ...            ...    ...          ...         ...        ...          ...
# 525525  2018-02-01  10:52       -2.245       3.505         10           52
# 525526  2018-02-01  10:53       -2.287       3.542         10           53
# 525527  2018-02-01  10:54       -2.418       3.643         10           54
# 525528  2018-02-01  10:55       -2.798       3.280         10           55
# 525529  2018-02-01  10:56       -2.466       2.946         10           56
#
#         month  day_of_week  day  week_of_year  ...  WindChillC  WindGustKmph  \
# 0           1            0    1             1  ...          -9            35
# 1           1            0    1             1  ...          -9            35
# 2           1            0    1             1  ...          -9            35
# 3           1            0    1             1  ...          -9            35
# 4           1            0    1             1  ...          -9            35
# ...       ...          ...  ...           ...  ...         ...           ...
# 525525      2            3    1             5  ...          16            22
# 525526      2            3    1             5  ...          16            22
# 525527      2            3    1             5  ...          16            22
# 525528      2            3    1             5  ...          16            22
# 525529      2            3    1             5  ...          16            22
#
#         cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# 0               74        54       0.0      1037     -2          10
# 1               74        54       0.0      1037     -2          10
# 2               74        54       0.0      1037     -2          10
# 3               74        54       0.0      1037     -2          10
# 4               74        54       0.0      1037     -2          10
# ...            ...       ...       ...       ...    ...         ...
# 525525          15        74       0.0      1016     17          10
# 525526          15        74       0.0      1016     17          10
# 525527          15        74       0.0      1016     17          10
# 525528          15        74       0.0      1016     17          10
# 525529          15        74       0.0      1016     17          10
#
#         winddirDegree  windspeedKmph
# 0                  12             25
# 1                  12             25
# 2                  12             25
# 3                  12             25
# 4                  12             25
# ...               ...            ...
# 525525            248             16
# 525526            248             16
# 525527            248             16
# 525528            248             16
# 525529            248             16
#
# [525530 rows x 29 columns]

# %%
features_df = features_df.sort_values(by=['date', 'hour'])
features_df
# Out:
#               date   hour  consumption  generation  time_hour  time_minute  \
# 441039  2018-01-01  00:00        0.691         0.0          0            0
# 441040  2018-01-01  00:01        0.689         0.0          0            1
# 441041  2018-01-01  00:02        0.688         0.0          0            2
# 441042  2018-01-01  00:03        0.688         0.0          0            3
# 441043  2018-01-01  00:04        0.687         0.0          0            4
# ...            ...    ...          ...         ...        ...          ...
# 440466  2018-12-31  23:55        1.754         0.0         23           55
# 440467  2018-12-31  23:56        1.737         0.0         23           56
# 440468  2018-12-31  23:57        1.736         0.0         23           57
# 440469  2018-12-31  23:58        1.757         0.0         23           58
# 440470  2018-12-31  23:59        2.106         0.0         23           59
#
#         month  day_of_week  day  week_of_year  ...  WindChillC  WindGustKmph  \
# 441039      1            0    1             1  ...          -9            34
# 441040      1            0    1             1  ...          -9            34
# 441041      1            0    1             1  ...          -9            34
# 441042      1            0    1             1  ...          -9            34
# 441043      1            0    1             1  ...          -9            34
# ...       ...          ...  ...           ...  ...         ...           ...
# 440466     12            0   31             1  ...          11            12
# 440467     12            0   31             1  ...          11            12
# 440468     12            0   31             1  ...          11            12
# 440469     12            0   31             1  ...          11            12
# 440470     12            0   31             1  ...          11            12
#
#         cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# 441039          93        57       0.0      1037     -2          10
# 441040          93        57       0.0      1037     -2          10
# 441041          93        57       0.0      1037     -2          10
# 441042          93        57       0.0      1037     -2          10
# 441043          93        57       0.0      1037     -2          10
# ...            ...       ...       ...       ...    ...         ...
# 440466           5        74       0.0      1017     10          10
# 440467           5        74       0.0      1017     10          10
# 440468           5        74       0.0      1017     10          10
# 440469           5        74       0.0      1017     10          10
# 440470           5        74       0.0      1017     10          10
#
#         winddirDegree  windspeedKmph
# 441039              9             25
# 441040              9             25
# 441041              9             25
# 441042              9             25
# 441043              9             25
# ...               ...            ...
# 440466            218              1
# 440467            218              1
# 440468            218              1
# 440469            218              1
# 440470            218              1
#
# [525530 rows x 29 columns]
