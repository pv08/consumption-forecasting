# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gru_MAE_Data = pd.read_csv("methodology/reports/All_Features/ALL_MAE_GRU.csv", sep=',')
RNN_MAE_Data = pd.read_csv("methodology/reports/All_Features/ALL_MAE_RNN.csv", sep=',')
LSTM_MAE_Data = pd.read_csv("methodology/reports/All_Features/ALL_MAE_LSTM.csv", sep=',')
PCA_LSTM_MAE_Data = pd.read_csv("methodology/reports/All_Features/PCA_MAE_LSTM.csv", sep=',')
RNN_Metrics = pd.read_csv("methodology/reports/All_Features/Local/ALL/ALL_Metrics_RNN.csv", sep=';')
TST_Metrics = pd.read_csv("methodology/reports/All_Features/Local/ALL/ALL_Metrics_TST.csv", sep=',')
SHAP_LSTM_Metrics = pd.read_csv("methodology/reports/All_Features/Local/Shap/SHAP_Metrics_LSTM.csv", sep=',')


gru_MSE_Data = pd.read_csv("methodology/reports/All_Features/ALL_MSE_GRU.csv", sep=',')

RNN_MSE_Data = pd.read_csv("methodology/reports/All_Features/ALL_MSE_RNN.csv", sep=',')
LSTM_MSE_Data = pd.read_csv("methodology/reports/All_Features/ALL_MSE_LSTM.csv", sep=',')
PCA_LSTM_MSE_Data = pd.read_csv("methodology/reports/All_Features/PCA_MSE_LSTM.csv", sep=',')

# %%
RNN_Metrics
# Out:
#      epoch     step  val/loss_epoch  val/val_mae  val/val_mse  val/rmse  \
# 0        0     5643        0.027038     0.134496     0.027038  0.134496
# 1        1    11287        0.011898     0.079093     0.011898  0.079093
# 2        2    16931        0.009685     0.067892     0.009685  0.067892
# 3        3    22575        0.009158     0.067741     0.009158  0.067741
# 4        4    28219        0.009485     0.072746     0.009485  0.072746
# ..     ...      ...             ...          ...          ...       ...
# 195    195  1106223        0.004582     0.049236     0.004582  0.049236
# 196    196  1111867        0.005733     0.054149     0.005733  0.054149
# 197    197  1117511        0.005060     0.051443     0.005060  0.051443
# 198    198  1123155        0.006325     0.054199     0.006325  0.054199
# 199    199  1128799        0.004836     0.044837     0.004836  0.044837
#
#      val/mape
# 0    0.495464
# 1    0.357918
# 2    0.327862
# 3    0.336564
# 4    0.347433
# ...

# %%
plt.figure(figsize=(20, 10))
plt.title(f'Baseline Models MAE', fontsize=15)
plt.plot(gru_MAE_Data.index, gru_MAE_Data['participant_id: 661_test_30 - val/rmse'], '^', ls='-',label='GRU')
plt.plot(RNN_Metrics.index, RNN_Metrics['val/val_mae'],'1', ms = 13, ls = '-', c = '#A52A2A',label='RNN')
plt.plot(LSTM_MAE_Data.index, LSTM_MAE_Data['participant_id: 661_test_30 - val/rmse'], ',', ms = 13, ls = '-', c = '#2E8B57', label='LSTM')
plt.xlabel('epochs', fontsize=15)
plt.ylabel('MAE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/local_baseline_models_MAE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/local_baseline_models_MAE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/local_baseline_models_MAE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(20, 10))
plt.title(f'MAE between PCA and normal training', fontsize=15)
plt.plot(LSTM_MAE_Data.index, LSTM_MAE_Data['participant_id: 661_test_30 - val/rmse'], ',', ms = 13, ls = '-', c = '#2E8B57', label='LSTM')
plt.plot(PCA_LSTM_MAE_Data.index, PCA_LSTM_MAE_Data['participant_id: 661_test_30_pca - val/val_mae'],'1', ms = 13, ls = '-', c = '#A52A2A',label='PCA-LSTM')

plt.xlabel('epochs', fontsize=15)
plt.ylabel('MAE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/PCA_LSTM_MAE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/PCA_LSTM_MAE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/PCA_LSTM_MAE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(20, 10))
plt.title(f'MAE between PCA, normal and SHAP training', fontsize=15)
plt.plot(LSTM_MAE_Data.index, LSTM_MAE_Data['participant_id: 661_test_30 - val/rmse'], ',', ms = 13, ls = '-', c = '#2E8B57', label='LSTM')
plt.plot(PCA_LSTM_MAE_Data.index, PCA_LSTM_MAE_Data['participant_id: 661_test_30_pca - val/val_mae'],'1', ms = 13, ls = '-', c = '#A52A2A',label='PCA-LSTM')
plt.plot(SHAP_LSTM_Metrics.index, SHAP_LSTM_Metrics['val/val_mae'],'1', ms = 13, ls = '-', c = '#080FFF',label='SHAP-LSTM')

plt.xlabel('epochs', fontsize=15)
plt.ylabel('MAE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/SHAP_LSTM_MAE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/SHAP_LSTM_MAE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/SHAP_LSTM_MAE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(20, 10))
plt.title(f'MSE between PCA, SHAP and normal training', fontsize=15)
plt.plot(LSTM_MSE_Data.index, LSTM_MSE_Data['participant_id: 661_test_30 - val/val_mse'], ',', ms = 13, ls = '-', c = '#2E8B57', label='LSTM')
plt.plot(PCA_LSTM_MSE_Data.index, PCA_LSTM_MSE_Data['participant_id: 661_test_30_pca - val/val_mse'],'1', ms = 13, ls = '-', c = '#A52A2A',label='PCA-LSTM')
plt.plot(SHAP_LSTM_Metrics.index, SHAP_LSTM_Metrics['val/val_mse'],'1', ms = 13, ls = '-', c = '#080FFF',label='SHAP-LSTM')

plt.xlabel('epochs', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/SHAP_LSTM_MSE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/SHAP_LSTM_MSE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/SHAP_LSTM_MSE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(20, 10))
plt.title(f'MSE between PCA and normal training', fontsize=15)
plt.plot(LSTM_MSE_Data.index, LSTM_MSE_Data['participant_id: 661_test_30 - val/val_mse'], ',', ms = 13, ls = '-', c = '#2E8B57', label='LSTM')
plt.plot(PCA_LSTM_MSE_Data.index, PCA_LSTM_MSE_Data['participant_id: 661_test_30_pca - val/val_mse'],'1', ms = 13, ls = '-', c = '#A52A2A',label='PCA-LSTM')

plt.xlabel('epochs', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/PCA_LSTM_MSE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/PCA_LSTM_MSE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/PCA_LSTM_MSE.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title(f'Baseline Models MSE', fontsize=15)
plt.plot(gru_MSE_Data.index, gru_MSE_Data['participant_id: 661_test_30 - val/val_mse'], '^', ls='-',label='GRU')
plt.plot(RNN_Metrics.index, RNN_Metrics['val/val_mse'],'1', ms = 13, ls = '-', c = '#A52A2A',label='RNN')
plt.plot(LSTM_MSE_Data.index, LSTM_MSE_Data['participant_id: 661_test_30 - val/val_mse'], ',', ms = 13, ls = '-', c = '#2E8B57', label='LSTM')
plt.xlabel('epochs', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/local_baseline_models_MSE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/local_baseline_models_MSE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/local_baseline_models_MSE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
TST_Metrics
# Out:
#      epoch    step  val/loss_epoch  val/val_mae  val/val_mse  val/rmse  \
# 0        0    2821        0.046635     0.163734     0.046635  0.163734
# 1        1    5643        0.061285     0.192046     0.061285  0.192046
# 2        2    8465        0.039049     0.142506     0.039049  0.142506
# 3        3   11287        0.052252     0.190577     0.052252  0.190577
# 4        4   14109        0.046424     0.185653     0.046424  0.185653
# ..     ...     ...             ...          ...          ...       ...
# 195    195  553111        0.005905     0.056634     0.005905  0.056634
# 196    196  555933        0.005617     0.056078     0.005617  0.056078
# 197    197  558755        0.006021     0.060219     0.006021  0.060219
# 198    198  561577        0.005628     0.055684     0.005628  0.055684
# 199    199  564399        0.007150     0.066999     0.007150  0.066999
#
#      val/mape
# 0    1.110145
# 1    1.311448
# 2    1.011420
# 3    1.068640
# 4    0.978713
# ..        ...
# ...

# %%
plt.figure(figsize=(20, 10))
plt.title(f'Baseline Models MSE', fontsize=15)
plt.plot(gru_MSE_Data.index, gru_MSE_Data['participant_id: 661_test_30 - val/val_mse'], '^', ls='-',label='GRU')
plt.plot(RNN_Metrics.index, RNN_Metrics['val/val_mse'],'1', ms = 13, ls = '-', c = '#A52A2A',label='RNN')
plt.plot(TST_Metrics.index, TST_Metrics['val/val_mse'], ms = 13, ls = '-', c = '#606D00', label='TST')
plt.xlabel('epochs', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/TST_baseline_models_comparison_MSE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/TST_baseline_models_comparison_MSE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/TST_baseline_models_comparison_MSE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(20, 10))
plt.title(f'Baseline Models MAE', fontsize=15)
plt.plot(gru_MAE_Data.index, gru_MAE_Data['participant_id: 661_test_30 - val/rmse'], '^', ls='-',label='GRU')
plt.plot(RNN_Metrics.index, RNN_Metrics['val/val_mae'],'1', ms = 13, ls = '-', c = '#A52A2A',label='RNN')
plt.plot(TST_Metrics.index, TST_Metrics['val/val_mae'], ms = 13, ls = '-', c = '#606D00', label='TST')
plt.xlabel('epochs', fontsize=15)
plt.ylabel('MAE', fontsize=15)
plt.legend(fontsize=15)
plt.savefig(f'methodology/imgs/results/metrics/TST_baseline_models_comparison_MAE.eps', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/TST_baseline_models_comparison_MAE.svg', dpi=600, bbox_inches='tight')
plt.savefig(f'methodology/imgs/results/metrics/TST_baseline_models_comparison_MAE.png', dpi=600, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
